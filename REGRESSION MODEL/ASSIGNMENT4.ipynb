# %% [markdown]
# ## Regression model with Keras
#
#
# <strong>The dataset is about the compressive strength of different samples of concrete based on the volumes of the different ingredients that were used to make them. Ingredients include:</strong>
#
# <strong>1. Cement</strong>
#
# <strong>2. Blast Furnace Slag</strong>
#
# <strong>3. Fly Ash</strong>
#
# <strong>4. Water</strong>
#
# <strong>5. Superplasticizer</strong>
#
# <strong>6. Coarse Aggregate</strong>
#
# <strong>7. Fine Aggregate</strong>
#
#
# ## Download and Clean Dataset
#
# Let's start by importing the <em>pandas</em> and the Numpy libraries.

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# %%
concrete_data = pd.read_csv('https://cocl.us/concrete_data')
concrete_data.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age  Strength
# 0            1040.0           676.0   28     79.99
# 1            1055.0           676.0   28     61.89
# 2             932.0           594.0  270     40.27
# 3             932.0           594.0  365     41.05
# 4             978.4           825.5  360     44.30

# %%
concrete_data.shape
# Out:
# (1030, 9)

# %%
concrete_data.describe()


concrete_data = (concrete_data - concrete_data.mean()) / concrete_data.std()
concrete_data.head()
# Out:
#      Cement  Blast Furnace Slag   Fly Ash     Water  Superplasticizer  \
# 0  2.476712           -0.856472 -0.846733 -0.916319         -0.620147
# 1  2.476712           -0.856472 -0.846733 -0.916319         -0.620147
# 2  0.491187            0.795140 -0.846733  2.174405         -1.038638
# 3  0.491187            0.795140 -0.846733  2.174405         -1.038638
# 4 -0.790075            0.678079 -0.846733  0.488555         -1.038638
#
#    Coarse Aggregate  Fine Aggregate       Age  Strength
# 0          0.862735       -1.217079 -0.279597  2.644123
# 1          1.055651       -1.217079 -0.279597  1.560663
# 2         -0.526262       -2.239829  3.551340  0.266498
# 3         -0.526262       -2.239829  5.055221  0.313188
# 4          0.070492        0.647569  4.976069  0.507732

# %%
concrete_data.isnull().sum()
# Out:
# Cement                0
# Blast Furnace Slag    0
# Fly Ash               0
# Water                 0
# Superplasticizer      0
# Coarse Aggregate      0
# Fine Aggregate        0
# Age                   0
# Strength              0
# dtype: int64

# %%
y = concrete_data
X = concrete_data

target=concrete_data['Strength']




X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.3)
print("\nX_train:\n")
print(X_train.head())
print(X_train.shape)

print("\nX_test:\n")
print(X_test.head())
print(X_test.shape)
# Out:
# X_train:
#
#        Cement  Blast Furnace Slag   Fly Ash     Water  Superplasticizer  \
# 649 -1.094363            2.043411 -0.846733  1.027091         -1.038638
# 419 -1.111587           -0.856472  1.397122 -0.832027         -1.038638
# 572 -0.577648            0.849614 -0.846733  0.193532         -1.038638
# 974 -1.273299           -0.856472  1.998713 -0.007834          1.472309
# 31  -0.145138            0.464818 -0.846733  2.174405         -1.038638
#
#      Coarse Aggregate  Fine Aggregate       Age  Strength
# 649          0.034481       -1.010034 -0.675355 -1.731019
# 419          0.420314        1.588001 -0.501222 -1.133620
# 572          1.055651       -0.365203 -0.612034 -1.360488
# 974         -1.723629        1.380956 -0.279597 -1.214430
# 31          -0.526262       -1.291914  5.055221  1.023124
# (721, 9)
#
# X_test:
#
#        Cement  Blast Furnace Slag   Fly Ash     Water  Superplasticizer  \
# 204 -0.660896           -0.856472  1.053356 -0.059346         -0.084478
# 51  -0.872367            1.345678 -0.846733  2.174405         -1.038638
# 376  0.907429           -0.856472 -0.846733  1.546894         -1.038638
# 593 -0.274317           -0.856472 -0.846733  0.193532         -1.038638
# 236 -0.644629            0.280533 -0.463902  0.006215          0.082918
#
#      Coarse Aggregate  Fine Aggregate       Age  Strength
# 204          1.089090        0.071337 -0.675355 -1.397601
# 51          -0.526262       -1.291914  2.126612  0.665163
# 376          0.393306       -0.139449 -0.279597 -0.230338
# 593          1.783589        0.133700 -0.612034 -1.456862
# 236          1.197123        0.148667 -0.279597  0.264103
# (309, 9)

# %% [markdown]
# ## Build a Neural Network

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense


n_cols = concrete_data.shape[1] # number of predictors

# %%
# define regression model
def regression_model():
    # create model
    model = Sequential()
    model.add(Dense(10, activation='relu', input_shape=(n_cols,)))
    model.add(Dense(10, activation='relu'))
    model.add(Dense(10, activation='relu'))
    model.add(Dense(1))
    
    # compile model
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

# %%
model = regression_model()
model.fit(concrete_data, target, validation_split=0.3, epochs=100, verbose=2)
# Out:
# Train on 721 samples, validate on 309 samples
# Epoch 1/100
#  - 0s - loss: 0.9944 - val_loss: 0.6999
# Epoch 2/100
#  - 0s - loss: 0.8431 - val_loss: 0.6018
# Epoch 3/100
#  - 0s - loss: 0.6529 - val_loss: 0.5011
# Epoch 4/100
#  - 0s - loss: 0.4589 - val_loss: 0.4166
# Epoch 5/100
#  - 0s - loss: 0.3220 - val_loss: 0.3581
# Epoch 6/100
#  - 0s - loss: 0.2329 - val_loss: 0.3122
# Epoch 7/100
#  - 0s - loss: 0.1698 - val_loss: 0.2687
# Epoch 8/100
#  - 0s - loss: 0.1289 - val_loss: 0.2536
# Epoch 9/100
#  - 0s - loss: 0.1017 - val_loss: 0.2234
# Epoch 10/100
#  - 0s - loss: 0.0823 - val_loss: 0.1956
# Epoch 11/100
#  - 0s - loss: 0.0681 - val_loss: 0.1803
# Epoch 12/100
#  - 0s - loss: 0.0567 - val_loss: 0.1656
# Epoch 13/100
#  - 0s - loss: 0.0490 - val_loss: 0.1485
# Epoch 14/100
#  - 0s - loss: 0.0432 - val_loss: 0.1367
# Epoch 15/100
#  - 0s - loss: 0.0386 - val_loss: 0.1335
# Epoch 16/100
#  - 0s - loss: 0.0344 - val_loss: 0.1242
# Epoch 17/100
#  - 0s - loss: 0.0315 - val_loss: 0.1165
# Epoch 18/100
#  - 0s - loss: 0.0292 - val_loss: 0.1103
# Epoch 19/100
#  - 0s - loss: 0.0270 - val_loss: 0.1045
# Epoch 20/100
#  - 0s - loss: 0.0250 - val_loss: 0.1022
# Epoch 21/100
#  - 0s - loss: 0.0233 - val_loss: 0.0991
# Epoch 22/100
#  - 0s - loss: 0.0223 - val_loss: 0.0897
# Epoch 23/100
#  - 0s - loss: 0.0205 - val_loss: 0.0866
# Epoch 24/100
#  - 0s - loss: 0.0193 - val_loss: 0.0790
# Epoch 25/100
#  - 0s - loss: 0.0181 - val_loss: 0.0752
# Epoch 26/100
#  - 0s - loss: 0.0169 - val_loss: 0.0710
# Epoch 27/100
#  - 0s - loss: 0.0158 - val_loss: 0.0675
# Epoch 28/100
#  - 0s - loss: 0.0150 - val_loss: 0.0635
# Epoch 29/100
#  - 0s - loss: 0.0139 - val_loss: 0.0603
# Epoch 30/100
#  - 0s - loss: 0.0130 - val_loss: 0.0549
# Epoch 31/100
#  - 0s - loss: 0.0121 - val_loss: 0.0505
# Epoch 32/100
#  - 0s - loss: 0.0113 - val_loss: 0.0493
# Epoch 33/100
#  - 0s - loss: 0.0106 - val_loss: 0.0460
# Epoch 34/100
#  - 0s - loss: 0.0104 - val_loss: 0.0427
# Epoch 35/100
#  - 0s - loss: 0.0094 - val_loss: 0.0411
# Epoch 36/100
#  - 0s - loss: 0.0091 - val_loss: 0.0389
# Epoch 37/100
#  - 0s - loss: 0.0085 - val_loss: 0.0374
# Epoch 38/100
#  - 0s - loss: 0.0080 - val_loss: 0.0356
# Epoch 39/100
#  - 0s - loss: 0.0077 - val_loss: 0.0352
# Epoch 40/100
#  - 0s - loss: 0.0073 - val_loss: 0.0357
# Epoch 41/100
#  - 0s - loss: 0.0069 - val_loss: 0.0330
# Epoch 42/100
#  - 0s - loss: 0.0066 - val_loss: 0.0335
# Epoch 43/100
#  - 0s - loss: 0.0063 - val_loss: 0.0298
# Epoch 44/100
#  - 0s - loss: 0.0060 - val_loss: 0.0295
# Epoch 45/100
#  - 0s - loss: 0.0057 - val_loss: 0.0294
# Epoch 46/100
#  - 0s - loss: 0.0055 - val_loss: 0.0281
# Epoch 47/100
#  - 0s - loss: 0.0053 - val_loss: 0.0270
# Epoch 48/100
#  - 0s - loss: 0.0051 - val_loss: 0.0268
# Epoch 49/100
#  - 0s - loss: 0.0049 - val_loss: 0.0263
# Epoch 50/100
#  - 0s - loss: 0.0047 - val_loss: 0.0253
# Epoch 51/100
#  - 0s - loss: 0.0045 - val_loss: 0.0237
# Epoch 52/100
#  - 0s - loss: 0.0044 - val_loss: 0.0237
# Epoch 53/100
#  - 0s - loss: 0.0043 - val_loss: 0.0228
# Epoch 54/100
#  - 0s - loss: 0.0040 - val_loss: 0.0217
# Epoch 55/100
#  - 0s - loss: 0.0039 - val_loss: 0.0217
# Epoch 56/100
#  - 0s - loss: 0.0038 - val_loss: 0.0213
# Epoch 57/100
#  - 0s - loss: 0.0037 - val_loss: 0.0197
# Epoch 58/100
#  - 0s - loss: 0.0036 - val_loss: 0.0192
# Epoch 59/100
#  - 0s - loss: 0.0034 - val_loss: 0.0193
# Epoch 60/100
#  - 0s - loss: 0.0033 - val_loss: 0.0180
# Epoch 61/100
#  - 0s - loss: 0.0032 - val_loss: 0.0181
# Epoch 62/100
#  - 0s - loss: 0.0032 - val_loss: 0.0175
# Epoch 63/100
#  - 0s - loss: 0.0030 - val_loss: 0.0176
# Epoch 64/100
#  - 0s - loss: 0.0030 - val_loss: 0.0164
# Epoch 65/100
#  - 0s - loss: 0.0028 - val_loss: 0.0160
# Epoch 66/100
#  - 0s - loss: 0.0028 - val_loss: 0.0153
# Epoch 67/100
#  - 0s - loss: 0.0028 - val_loss: 0.0149
# Epoch 68/100
#  - 0s - loss: 0.0026 - val_loss: 0.0144
# Epoch 69/100
#  - 0s - loss: 0.0025 - val_loss: 0.0144
# Epoch 70/100
#  - 0s - loss: 0.0024 - val_loss: 0.0137
# Epoch 71/100
#  - 0s - loss: 0.0023 - val_loss: 0.0136
# Epoch 72/100
#  - 0s - loss: 0.0023 - val_loss: 0.0131
# Epoch 73/100
#  - 0s - loss: 0.0023 - val_loss: 0.0129
# Epoch 74/100
#  - 0s - loss: 0.0022 - val_loss: 0.0123
# Epoch 75/100
#  - 0s - loss: 0.0021 - val_loss: 0.0124
# Epoch 76/100
#  - 0s - loss: 0.0021 - val_loss: 0.0122
# Epoch 77/100
#  - 0s - loss: 0.0021 - val_loss: 0.0120
# Epoch 78/100
#  - 0s - loss: 0.0019 - val_loss: 0.0113
# Epoch 79/100
#  - 0s - loss: 0.0020 - val_loss: 0.0115
# Epoch 80/100
#  - 0s - loss: 0.0019 - val_loss: 0.0111
# Epoch 81/100
#  - 0s - loss: 0.0018 - val_loss: 0.0111
# Epoch 82/100
#  - 0s - loss: 0.0018 - val_loss: 0.0110
# Epoch 83/100
#  - 0s - loss: 0.0018 - val_loss: 0.0112
# Epoch 84/100
#  - 0s - loss: 0.0018 - val_loss: 0.0105
# Epoch 85/100
#  - 0s - loss: 0.0017 - val_loss: 0.0102
# Epoch 86/100
#  - 0s - loss: 0.0016 - val_loss: 0.0104
# Epoch 87/100
#  - 0s - loss: 0.0016 - val_loss: 0.0102
# Epoch 88/100
#  - 0s - loss: 0.0015 - val_loss: 0.0097
# Epoch 89/100
#  - 0s - loss: 0.0015 - val_loss: 0.0097
# Epoch 90/100
#  - 0s - loss: 0.0015 - val_loss: 0.0095
# Epoch 91/100
#  - 0s - loss: 0.0014 - val_loss: 0.0097
# Epoch 92/100
#  - 0s - loss: 0.0014 - val_loss: 0.0095
# Epoch 93/100
#  - 0s - loss: 0.0014 - val_loss: 0.0092
# Epoch 94/100
#  - 0s - loss: 0.0013 - val_loss: 0.0094
# Epoch 95/100
#  - 0s - loss: 0.0013 - val_loss: 0.0093
# Epoch 96/100
#  - 0s - loss: 0.0013 - val_loss: 0.0092
# Epoch 97/100
#  - 0s - loss: 0.0013 - val_loss: 0.0089
# Epoch 98/100
#  - 0s - loss: 0.0013 - val_loss: 0.0093
# Epoch 99/100
#  - 0s - loss: 0.0013 - val_loss: 0.0088
# Epoch 100/100
#  - 0s - loss: 0.0012 - val_loss: 0.0087
