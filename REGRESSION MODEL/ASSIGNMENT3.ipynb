# %% [markdown]
# ## Regression model with Keras
#
#
# <strong>The dataset is about the compressive strength of different samples of concrete based on the volumes of the different ingredients that were used to make them. Ingredients include:</strong>
#
# <strong>1. Cement</strong>
#
# <strong>2. Blast Furnace Slag</strong>
#
# <strong>3. Fly Ash</strong>
#
# <strong>4. Water</strong>
#
# <strong>5. Superplasticizer</strong>
#
# <strong>6. Coarse Aggregate</strong>
#
# <strong>7. Fine Aggregate</strong>
#
#
# ## Download and Clean Dataset
#
# Let's start by importing the <em>pandas</em> and the Numpy libraries.

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# %%
concrete_data = pd.read_csv('https://cocl.us/concrete_data')
concrete_data.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age  Strength
# 0            1040.0           676.0   28     79.99
# 1            1055.0           676.0   28     61.89
# 2             932.0           594.0  270     40.27
# 3             932.0           594.0  365     41.05
# 4             978.4           825.5  360     44.30

# %%
concrete_data.shape
# Out:
# (1030, 9)

# %%
concrete_data.describe()


concrete_data = (concrete_data - concrete_data.mean()) / concrete_data.std()
concrete_data.head()
# Out:
#      Cement  Blast Furnace Slag   Fly Ash     Water  Superplasticizer  \
# 0  2.476712           -0.856472 -0.846733 -0.916319         -0.620147
# 1  2.476712           -0.856472 -0.846733 -0.916319         -0.620147
# 2  0.491187            0.795140 -0.846733  2.174405         -1.038638
# 3  0.491187            0.795140 -0.846733  2.174405         -1.038638
# 4 -0.790075            0.678079 -0.846733  0.488555         -1.038638
#
#    Coarse Aggregate  Fine Aggregate       Age  Strength
# 0          0.862735       -1.217079 -0.279597  2.644123
# 1          1.055651       -1.217079 -0.279597  1.560663
# 2         -0.526262       -2.239829  3.551340  0.266498
# 3         -0.526262       -2.239829  5.055221  0.313188
# 4          0.070492        0.647569  4.976069  0.507732

# %%
concrete_data.isnull().sum()
# Out:
# Cement                0
# Blast Furnace Slag    0
# Fly Ash               0
# Water                 0
# Superplasticizer      0
# Coarse Aggregate      0
# Fine Aggregate        0
# Age                   0
# Strength              0
# dtype: int64

# %%
y = concrete_data
X = concrete_data

target=concrete_data['Strength']




X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.3)
print("\nX_train:\n")
print(X_train.head())
print(X_train.shape)

print("\nX_test:\n")
print(X_test.head())
print(X_test.shape)
# Out:
# X_train:
#
#        Cement  Blast Furnace Slag   Fly Ash     Water  Superplasticizer  \
# 292 -0.948917           -0.332592  1.059607 -0.532320          0.334013
# 111  0.779207            1.334087 -0.846733 -0.780515          0.903161
# 277 -0.284843           -0.856472  1.001791  0.324653         -0.067739
# 981 -1.299135           -0.856472  1.948711  0.942798          0.267054
# 39  -0.417849            1.896215 -0.846733  2.174405         -1.038638
#
#      Coarse Aggregate  Fine Aggregate       Age  Strength
# 292          1.112240        0.088799  0.163652  0.459844
# 111         -0.362926       -0.221768 -0.612034  1.202104
# 277          0.713547       -0.198070  0.163652  0.068961
# 981         -1.915259        1.186384 -0.279597 -1.513130
# 39          -0.526262       -2.239829  2.126612  0.025862
# (721, 9)
#
# X_test:
#
#        Cement  Blast Furnace Slag   Fly Ash     Water  Superplasticizer  \
# 549  0.495971           -0.856472 -0.846733  0.488555         -1.038638
# 911 -1.274256           -0.856472  1.997151 -0.026565          1.472309
# 211 -0.489615           -0.856472  1.001791  0.652457         -0.268614
# 462 -1.040777           -0.698844  1.847144 -1.159831         -0.352313
# 544  0.074944           -0.856472 -0.846733  0.488555         -1.038638
#
#      Coarse Aggregate  Fine Aggregate       Age  Strength
# 549         -0.536551        0.860850  0.701883  0.350900
# 911         -1.722342        1.377214 -0.279597 -1.215029
# 211          0.726408       -0.186845 -0.279597 -0.678686
# 462          0.429317        1.032972  0.860186  0.111461
# 544         -0.768050        1.518154 -0.612034 -1.270100
# (309, 9)

# %% [markdown]
# ## Build a Neural Network

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense


n_cols = concrete_data.shape[1] # number of predictors

# %%
# define regression model
def regression_model():
    # create model
    model = Sequential()
    model.add(Dense(10, activation='relu', input_shape=(n_cols,)))
    model.add(Dense(1))
    
    # compile model
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

# %%
model = regression_model()
model.fit(concrete_data, target, validation_split=0.3, epochs=100, verbose=2)
# Out:
# Train on 721 samples, validate on 309 samples
# Epoch 1/100
#  - 0s - loss: 2.3548 - val_loss: 2.5430
# Epoch 2/100
#  - 0s - loss: 1.8612 - val_loss: 2.0624
# Epoch 3/100
#  - 0s - loss: 1.5170 - val_loss: 1.7076
# Epoch 4/100
#  - 0s - loss: 1.2644 - val_loss: 1.4458
# Epoch 5/100
#  - 0s - loss: 1.0759 - val_loss: 1.2490
# Epoch 6/100
#  - 0s - loss: 0.9334 - val_loss: 1.0879
# Epoch 7/100
#  - 0s - loss: 0.8168 - val_loss: 0.9625
# Epoch 8/100
#  - 0s - loss: 0.7217 - val_loss: 0.8553
# Epoch 9/100
#  - 0s - loss: 0.6424 - val_loss: 0.7706
# Epoch 10/100
#  - 0s - loss: 0.5759 - val_loss: 0.6996
# Epoch 11/100
#  - 0s - loss: 0.5199 - val_loss: 0.6401
# Epoch 12/100
#  - 0s - loss: 0.4717 - val_loss: 0.5882
# Epoch 13/100
#  - 0s - loss: 0.4296 - val_loss: 0.5442
# Epoch 14/100
#  - 0s - loss: 0.3924 - val_loss: 0.5040
# Epoch 15/100
#  - 0s - loss: 0.3594 - val_loss: 0.4682
# Epoch 16/100
#  - 0s - loss: 0.3295 - val_loss: 0.4352
# Epoch 17/100
#  - 0s - loss: 0.3027 - val_loss: 0.4070
# Epoch 18/100
#  - 0s - loss: 0.2789 - val_loss: 0.3803
# Epoch 19/100
#  - 0s - loss: 0.2567 - val_loss: 0.3545
# Epoch 20/100
#  - 0s - loss: 0.2360 - val_loss: 0.3306
# Epoch 21/100
#  - 0s - loss: 0.2174 - val_loss: 0.3086
# Epoch 22/100
#  - 0s - loss: 0.1992 - val_loss: 0.2875
# Epoch 23/100
#  - 0s - loss: 0.1825 - val_loss: 0.2655
# Epoch 24/100
#  - 0s - loss: 0.1662 - val_loss: 0.2464
# Epoch 25/100
#  - 0s - loss: 0.1509 - val_loss: 0.2259
# Epoch 26/100
#  - 0s - loss: 0.1364 - val_loss: 0.2081
# Epoch 27/100
#  - 0s - loss: 0.1229 - val_loss: 0.1926
# Epoch 28/100
#  - 0s - loss: 0.1103 - val_loss: 0.1772
# Epoch 29/100
#  - 0s - loss: 0.0987 - val_loss: 0.1633
# Epoch 30/100
#  - 0s - loss: 0.0884 - val_loss: 0.1503
# Epoch 31/100
#  - 0s - loss: 0.0794 - val_loss: 0.1384
# Epoch 32/100
#  - 0s - loss: 0.0714 - val_loss: 0.1283
# Epoch 33/100
#  - 0s - loss: 0.0642 - val_loss: 0.1182
# Epoch 34/100
#  - 0s - loss: 0.0581 - val_loss: 0.1098
# Epoch 35/100
#  - 0s - loss: 0.0530 - val_loss: 0.1014
# Epoch 36/100
#  - 0s - loss: 0.0487 - val_loss: 0.0945
# Epoch 37/100
#  - 0s - loss: 0.0449 - val_loss: 0.0895
# Epoch 38/100
#  - 0s - loss: 0.0421 - val_loss: 0.0844
# Epoch 39/100
#  - 0s - loss: 0.0394 - val_loss: 0.0804
# Epoch 40/100
#  - 0s - loss: 0.0372 - val_loss: 0.0770
# Epoch 41/100
#  - 0s - loss: 0.0353 - val_loss: 0.0732
# Epoch 42/100
#  - 0s - loss: 0.0336 - val_loss: 0.0709
# Epoch 43/100
#  - 0s - loss: 0.0322 - val_loss: 0.0685
# Epoch 44/100
#  - 0s - loss: 0.0311 - val_loss: 0.0665
# Epoch 45/100
#  - 0s - loss: 0.0299 - val_loss: 0.0645
# Epoch 46/100
#  - 0s - loss: 0.0290 - val_loss: 0.0628
# Epoch 47/100
#  - 0s - loss: 0.0282 - val_loss: 0.0608
# Epoch 48/100
#  - 0s - loss: 0.0274 - val_loss: 0.0598
# Epoch 49/100
#  - 0s - loss: 0.0268 - val_loss: 0.0588
# Epoch 50/100
#  - 0s - loss: 0.0261 - val_loss: 0.0568
# Epoch 51/100
#  - 0s - loss: 0.0255 - val_loss: 0.0563
# Epoch 52/100
#  - 0s - loss: 0.0249 - val_loss: 0.0548
# Epoch 53/100
#  - 0s - loss: 0.0244 - val_loss: 0.0537
# Epoch 54/100
#  - 0s - loss: 0.0238 - val_loss: 0.0530
# Epoch 55/100
#  - 0s - loss: 0.0234 - val_loss: 0.0514
# Epoch 56/100
#  - 0s - loss: 0.0227 - val_loss: 0.0510
# Epoch 57/100
#  - 0s - loss: 0.0223 - val_loss: 0.0498
# Epoch 58/100
#  - 0s - loss: 0.0218 - val_loss: 0.0487
# Epoch 59/100
#  - 0s - loss: 0.0214 - val_loss: 0.0479
# Epoch 60/100
#  - 0s - loss: 0.0209 - val_loss: 0.0467
# Epoch 61/100
#  - 0s - loss: 0.0205 - val_loss: 0.0464
# Epoch 62/100
#  - 0s - loss: 0.0201 - val_loss: 0.0454
# Epoch 63/100
#  - 0s - loss: 0.0197 - val_loss: 0.0445
# Epoch 64/100
#  - 0s - loss: 0.0193 - val_loss: 0.0439
# Epoch 65/100
#  - 0s - loss: 0.0189 - val_loss: 0.0430
# Epoch 66/100
#  - 0s - loss: 0.0186 - val_loss: 0.0424
# Epoch 67/100
#  - 0s - loss: 0.0183 - val_loss: 0.0410
# Epoch 68/100
#  - 0s - loss: 0.0179 - val_loss: 0.0408
# Epoch 69/100
#  - 0s - loss: 0.0176 - val_loss: 0.0402
# Epoch 70/100
#  - 0s - loss: 0.0173 - val_loss: 0.0391
# Epoch 71/100
#  - 0s - loss: 0.0170 - val_loss: 0.0385
# Epoch 72/100
#  - 0s - loss: 0.0167 - val_loss: 0.0382
# Epoch 73/100
#  - 0s - loss: 0.0164 - val_loss: 0.0368
# Epoch 74/100
#  - 0s - loss: 0.0161 - val_loss: 0.0364
# Epoch 75/100
#  - 0s - loss: 0.0159 - val_loss: 0.0359
# Epoch 76/100
#  - 0s - loss: 0.0156 - val_loss: 0.0351
# Epoch 77/100
#  - 0s - loss: 0.0153 - val_loss: 0.0342
# Epoch 78/100
#  - 0s - loss: 0.0150 - val_loss: 0.0337
# Epoch 79/100
#  - 0s - loss: 0.0148 - val_loss: 0.0330
# Epoch 80/100
#  - 0s - loss: 0.0146 - val_loss: 0.0325
# Epoch 81/100
#  - 0s - loss: 0.0143 - val_loss: 0.0323
# Epoch 82/100
#  - 0s - loss: 0.0140 - val_loss: 0.0312
# Epoch 83/100
#  - 0s - loss: 0.0138 - val_loss: 0.0310
# Epoch 84/100
#  - 0s - loss: 0.0136 - val_loss: 0.0301
# Epoch 85/100
#  - 0s - loss: 0.0134 - val_loss: 0.0296
# Epoch 86/100
#  - 0s - loss: 0.0131 - val_loss: 0.0291
# Epoch 87/100
#  - 0s - loss: 0.0130 - val_loss: 0.0288
# Epoch 88/100
#  - 0s - loss: 0.0128 - val_loss: 0.0280
# Epoch 89/100
#  - 0s - loss: 0.0125 - val_loss: 0.0277
# Epoch 90/100
#  - 0s - loss: 0.0124 - val_loss: 0.0274
# Epoch 91/100
#  - 0s - loss: 0.0122 - val_loss: 0.0269
# Epoch 92/100
#  - 0s - loss: 0.0120 - val_loss: 0.0264
# Epoch 93/100
#  - 0s - loss: 0.0118 - val_loss: 0.0257
# Epoch 94/100
#  - 0s - loss: 0.0117 - val_loss: 0.0258
# Epoch 95/100
#  - 0s - loss: 0.0115 - val_loss: 0.0251
# Epoch 96/100
#  - 0s - loss: 0.0113 - val_loss: 0.0248
# Epoch 97/100
#  - 0s - loss: 0.0111 - val_loss: 0.0243
# Epoch 98/100
#  - 0s - loss: 0.0110 - val_loss: 0.0239
# Epoch 99/100
#  - 0s - loss: 0.0109 - val_loss: 0.0234
# Epoch 100/100
#  - 0s - loss: 0.0106 - val_loss: 0.0231
