# %% [markdown]
# ## Regression model with Keras
#
#
# <strong>The dataset is about the compressive strength of different samples of concrete based on the volumes of the different ingredients that were used to make them. Ingredients include:</strong>
#
# <strong>1. Cement</strong>
#
# <strong>2. Blast Furnace Slag</strong>
#
# <strong>3. Fly Ash</strong>
#
# <strong>4. Water</strong>
#
# <strong>5. Superplasticizer</strong>
#
# <strong>6. Coarse Aggregate</strong>
#
# <strong>7. Fine Aggregate</strong>
#
#
# ## Download and Clean Dataset
#
# Let's start by importing the <em>pandas</em> and the Numpy libraries.

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# %%
concrete_data = pd.read_csv('https://cocl.us/concrete_data')
concrete_data.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age  Strength
# 0            1040.0           676.0   28     79.99
# 1            1055.0           676.0   28     61.89
# 2             932.0           594.0  270     40.27
# 3             932.0           594.0  365     41.05
# 4             978.4           825.5  360     44.30

# %%
concrete_data.shape
# Out:
# (1030, 9)

# %%
concrete_data.describe()


concrete_data = (concrete_data - concrete_data.mean()) / concrete_data.std()
concrete_data.head()
# Out:
#      Cement  Blast Furnace Slag   Fly Ash     Water  Superplasticizer  \
# 0  2.476712           -0.856472 -0.846733 -0.916319         -0.620147
# 1  2.476712           -0.856472 -0.846733 -0.916319         -0.620147
# 2  0.491187            0.795140 -0.846733  2.174405         -1.038638
# 3  0.491187            0.795140 -0.846733  2.174405         -1.038638
# 4 -0.790075            0.678079 -0.846733  0.488555         -1.038638
#
#    Coarse Aggregate  Fine Aggregate       Age  Strength
# 0          0.862735       -1.217079 -0.279597  2.644123
# 1          1.055651       -1.217079 -0.279597  1.560663
# 2         -0.526262       -2.239829  3.551340  0.266498
# 3         -0.526262       -2.239829  5.055221  0.313188
# 4          0.070492        0.647569  4.976069  0.507732

# %%
concrete_data.isnull().sum()
# Out:
# Cement                0
# Blast Furnace Slag    0
# Fly Ash               0
# Water                 0
# Superplasticizer      0
# Coarse Aggregate      0
# Fine Aggregate        0
# Age                   0
# Strength              0
# dtype: int64

# %%
y = concrete_data
X = concrete_data

target=concrete_data['Strength']




X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.3)
print("\nX_train:\n")
print(X_train.head())
print(X_train.shape)

print("\nX_test:\n")
print(X_test.head())
print(X_test.shape)
# Out:
# X_train:
#
#        Cement  Blast Furnace Slag   Fly Ash     Water  Superplasticizer  \
# 292 -0.948917           -0.332592  1.059607 -0.532320          0.334013
# 111  0.779207            1.334087 -0.846733 -0.780515          0.903161
# 277 -0.284843           -0.856472  1.001791  0.324653         -0.067739
# 981 -1.299135           -0.856472  1.948711  0.942798          0.267054
# 39  -0.417849            1.896215 -0.846733  2.174405         -1.038638
#
#      Coarse Aggregate  Fine Aggregate       Age  Strength
# 292          1.112240        0.088799  0.163652  0.459844
# 111         -0.362926       -0.221768 -0.612034  1.202104
# 277          0.713547       -0.198070  0.163652  0.068961
# 981         -1.915259        1.186384 -0.279597 -1.513130
# 39          -0.526262       -2.239829  2.126612  0.025862
# (721, 9)
#
# X_test:
#
#        Cement  Blast Furnace Slag   Fly Ash     Water  Superplasticizer  \
# 549  0.495971           -0.856472 -0.846733  0.488555         -1.038638
# 911 -1.274256           -0.856472  1.997151 -0.026565          1.472309
# 211 -0.489615           -0.856472  1.001791  0.652457         -0.268614
# 462 -1.040777           -0.698844  1.847144 -1.159831         -0.352313
# 544  0.074944           -0.856472 -0.846733  0.488555         -1.038638
#
#      Coarse Aggregate  Fine Aggregate       Age  Strength
# 549         -0.536551        0.860850  0.701883  0.350900
# 911         -1.722342        1.377214 -0.279597 -1.215029
# 211          0.726408       -0.186845 -0.279597 -0.678686
# 462          0.429317        1.032972  0.860186  0.111461
# 544         -0.768050        1.518154 -0.612034 -1.270100
# (309, 9)

# %% [markdown]
# ## Build a Neural Network

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense


n_cols = concrete_data.shape[1] # number of predictors

# %%
# define regression model
def regression_model():
    # create model
    model = Sequential()
    model.add(Dense(10, activation='relu', input_shape=(n_cols,)))
    model.add(Dense(1))
    
    # compile model
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

# %%
model = regression_model()
model.fit(concrete_data, target, validation_split=0.3, epochs=50, verbose=2)
# Out:
# Train on 721 samples, validate on 309 samples
# Epoch 1/50
#  - 0s - loss: 2.6081 - val_loss: 1.0880
# Epoch 2/50
#  - 0s - loss: 2.0443 - val_loss: 0.9225
# Epoch 3/50
#  - 0s - loss: 1.6215 - val_loss: 0.7867
# Epoch 4/50
#  - 0s - loss: 1.3345 - val_loss: 0.6680
# Epoch 5/50
#  - 0s - loss: 1.1033 - val_loss: 0.5782
# Epoch 6/50
#  - 0s - loss: 0.9273 - val_loss: 0.5046
# Epoch 7/50
#  - 0s - loss: 0.7735 - val_loss: 0.4464
# Epoch 8/50
#  - 0s - loss: 0.6509 - val_loss: 0.3910
# Epoch 9/50
#  - 0s - loss: 0.5520 - val_loss: 0.3489
# Epoch 10/50
#  - 0s - loss: 0.4715 - val_loss: 0.3129
# Epoch 11/50
#  - 0s - loss: 0.4089 - val_loss: 0.2835
# Epoch 12/50
#  - 0s - loss: 0.3532 - val_loss: 0.2582
# Epoch 13/50
#  - 0s - loss: 0.3078 - val_loss: 0.2377
# Epoch 14/50
#  - 0s - loss: 0.2692 - val_loss: 0.2209
# Epoch 15/50
#  - 0s - loss: 0.2379 - val_loss: 0.2046
# Epoch 16/50
#  - 0s - loss: 0.2110 - val_loss: 0.1921
# Epoch 17/50
#  - 0s - loss: 0.1885 - val_loss: 0.1856
# Epoch 18/50
#  - 0s - loss: 0.1689 - val_loss: 0.1765
# Epoch 19/50
#  - 0s - loss: 0.1516 - val_loss: 0.1695
# Epoch 20/50
#  - 0s - loss: 0.1365 - val_loss: 0.1627
# Epoch 21/50
#  - 0s - loss: 0.1227 - val_loss: 0.1584
# Epoch 22/50
#  - 0s - loss: 0.1108 - val_loss: 0.1526
# Epoch 23/50
#  - 0s - loss: 0.1012 - val_loss: 0.1490
# Epoch 24/50
#  - 0s - loss: 0.0928 - val_loss: 0.1451
# Epoch 25/50
#  - 0s - loss: 0.0858 - val_loss: 0.1399
# Epoch 26/50
#  - 0s - loss: 0.0801 - val_loss: 0.1362
# Epoch 27/50
#  - 0s - loss: 0.0752 - val_loss: 0.1319
# Epoch 28/50
#  - 0s - loss: 0.0709 - val_loss: 0.1277
# Epoch 29/50
#  - 0s - loss: 0.0671 - val_loss: 0.1250
# Epoch 30/50
#  - 0s - loss: 0.0636 - val_loss: 0.1211
# Epoch 31/50
#  - 0s - loss: 0.0609 - val_loss: 0.1193
# Epoch 32/50
#  - 0s - loss: 0.0581 - val_loss: 0.1161
# Epoch 33/50
#  - 0s - loss: 0.0557 - val_loss: 0.1123
# Epoch 34/50
#  - 0s - loss: 0.0535 - val_loss: 0.1105
# Epoch 35/50
#  - 0s - loss: 0.0514 - val_loss: 0.1083
# Epoch 36/50
#  - 0s - loss: 0.0495 - val_loss: 0.1049
# Epoch 37/50
#  - 0s - loss: 0.0476 - val_loss: 0.1018
# Epoch 38/50
#  - 0s - loss: 0.0458 - val_loss: 0.0996
# Epoch 39/50
#  - 0s - loss: 0.0442 - val_loss: 0.0973
# Epoch 40/50
#  - 0s - loss: 0.0427 - val_loss: 0.0937
# Epoch 41/50
#  - 0s - loss: 0.0414 - val_loss: 0.0914
# Epoch 42/50
#  - 0s - loss: 0.0398 - val_loss: 0.0889
# Epoch 43/50
#  - 0s - loss: 0.0385 - val_loss: 0.0878
# Epoch 44/50
#  - 0s - loss: 0.0372 - val_loss: 0.0851
# Epoch 45/50
#  - 0s - loss: 0.0360 - val_loss: 0.0831
# Epoch 46/50
#  - 0s - loss: 0.0348 - val_loss: 0.0813
# Epoch 47/50
#  - 0s - loss: 0.0338 - val_loss: 0.0784
# Epoch 48/50
#  - 0s - loss: 0.0326 - val_loss: 0.0766
# Epoch 49/50
#  - 0s - loss: 0.0316 - val_loss: 0.0738
# Epoch 50/50
#  - 0s - loss: 0.0308 - val_loss: 0.0727
